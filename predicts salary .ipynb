# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/Salaries.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.head(10)
# Out:
#         rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0       Prof          B             19           18    Male  139750
# 1       Prof          B             20           16    Male  173200
# 2   AsstProf          B              4            3    Male   79750
# 3       Prof          B             45           39    Male  115000
# 4       Prof          B             40           41    Male  141500
# 5  AssocProf          B              6            6    Male   97000
# 6       Prof          B             30           23    Male  175000
# 7       Prof          B             45           45    Male  147765
# 8       Prof          B             21           20    Male  119250
# 9       Prof          B             18           18  Female  129000

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
data_columns=['yrs.service','salary']

# %%
data=data[data_columns].copy()

# %%
salary_df=data.rename({'Yrs.service':'yrs.service','Salary':'salary'})

# %%
salary_df.head()
# Out:
#    yrs.service  salary
# 0           18  139750
# 1           16  173200
# 2            3   79750
# 3           39  115000
# 4           41  141500

# %%
salary_df
# Out:
#      yrs.service  salary
# 0             18  139750
# 1             16  173200
# 2              3   79750
# 3             39  115000
# 4             41  141500
# ..           ...     ...
# 392           30  103106
# 393           19  150564
# 394           25  101738
# 395           15   95329
# 396            4   81035
#
# [397 rows x 2 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(x="yrs.service", y="salary",data=salary_df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
df.corr()["salary"]
# Out:
# yrs.service    0.334745
# salary         1.000000
# Name: salary, dtype: float64

# %%
x=salary_df.iloc[:,:-1].values
y=salary_df.iloc[:,-1].values

# %%
x
# Out:
# array([[18],
#        [16],
#        [ 3],
#        [39],
#        [41],
#        [ 6],
#        [23],
#        [45],
#        [20],
#        [18],
#        [ 8],
#        [ 2],
#        [ 1],
#        [ 0],
#        [18],
#        [ 3],
#        [20],
#        [34],
#        [23],
#        [36],
#        [26],
#        [31],
#        [30],
#        [19],
#        [ 8],
#        [ 8],
#        [23],
#        [ 3],
#        [ 0],
#        [ 8],
#        [ 4],
#        [ 2],
#        [ 9],
#        [ 2],
#        [ 2],
#        [ 0],
#        [21],
#        [ 4],
#        [31],
#        [ 9],
#        [ 2],
#        [23],
#        [27],
#        [38],
#        [19],
#        [15],
#        [28],
#        [19],
#        [25],
#        [ 1],
#        [28],
#        [11],
#        [ 3],
#        [ 9],
#        [11],
#        [ 5],
#        [21],
#        [ 8],
#        [ 9],
#        [ 3],
#        [ 8],
#        [ 2],
#        [31],
#        [11],
#        [ 3],
#        [ 8],
# ...

# %%
y
# Out:
# array([139750, 173200,  79750, 115000, 141500,  97000, 175000, 147765,
#        119250, 129000, 119800,  79800,  77700,  78000, 104800, 117150,
#        101000, 103450, 124750, 137000,  89565, 102580,  93904, 113068,
#         74830, 106294, 134885,  82379,  77000, 118223, 132261,  79916,
#        117256,  80225,  80225,  77000, 155750,  86373, 125196, 100938,
#        146500,  93418, 101299, 231545,  94384, 114778,  98193, 151768,
#        140096,  70768, 126621, 108875,  74692, 106639, 103760,  83900,
#        117704,  90215, 100135,  75044,  90304,  75243, 109785, 103613,
#         68404, 100522, 101000,  99418, 111512,  91412, 126320, 146856,
#        100131,  92391, 113398,  73266, 150480, 193000,  86100,  84240,
#        150743, 135585, 144640,  88825, 122960, 132825, 152708,  88400,
#        172272, 107008,  97032, 105128, 105631, 166024, 123683,  84000,
#         95611, 129676, 102235, 106689, 133217, 126933, 153303, 127512,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=100)

# %%
x_train.size
# Out:
# 264

# %%
x_test.size
# Out:
# 133

# %%
y_train
# Out:
# array([134885, 189409,  77000, 167284, 100938, 127100, 105350, 119800,
#         91300,  86895, 126431, 151575, 100522, 128800, 114000, 125192,
#        156938,  93418,  70000, 103994,  83850, 113278, 122400,  89516,
#        106608,  80139, 146500, 144309, 117256, 140096, 105450, 162200,
#         62884,  73800, 204000,  75243, 146856,  92050, 151445, 155500,
#        120806,  93000, 132825, 137167,  88795,  74692, 103106,  92000,
#        109646, 104428, 118223, 104121, 152664, 122500, 162221,  98510,
#         82100, 113600, 100944,  74856, 119500, 111751, 107309, 134778,
#        168500, 119700, 109785, 194800, 106689, 116450,  72500,  86373,
#        153750, 132000, 131950,  88825, 144050, 134800, 108875, 104350,
#        142023, 103649, 101299, 138771, 166605, 150500, 101036,  92000,
#         88400,  73000,  83900,  93904,  97150, 134550, 126933,  79800,
#        126300,  81500, 172505,  90000, 106294, 117515, 135585, 110515,
# ...

# %%
y_test
# Out:
# array([124714, 103760,  86100, 181257, 108413, 163200, 129676,  69700,
#        126200, 121946, 105000,  93519, 133700,  96545, 117704, 114500,
#        183800, 151292, 128148,  72500,  73000,  83000,  95642, 103600,
#         81800,  95408, 122875,  73266,  74000, 147765, 107986, 124750,
#         72300, 112429, 134185,  74000, 133900, 115435,  73300,  95611,
#         77000, 231545,  72500, 101100, 176500,  80225, 108262, 173200,
#        126000, 145028, 100351, 102580, 103275, 111168,  88600, 124309,
#         57800, 136660, 127512, 150680, 165000,  92550, 101000, 102235,
#        116518,  89942,  88600, 168635,  81700,  68404, 135027,  97000,
#        128250,  96614,  92000, 143940,  91412,  96200,  98193, 126621,
#         95079,  72500,  85000, 107500, 180000, 170500,  82379, 105000,
#         84273, 134690, 145098, 124312,  77081, 166800, 104800,  97032,
#        175000, 106300,  75996,  78162, 111350,  88650, 115000,  89565,
# ...

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_LR=LR.predict(x_test)

# %%
y_pred_LR
# Out:
# array([111479.40414163, 107936.42203178,  99078.96675714, 114136.64072402,
#         99078.96675714, 115908.13177895, 104393.43992192, 100850.45781206,
#        115022.38625149, 107936.42203178, 103507.69439446, 131851.5512733 ,
#        117679.62283388,  99964.7122846 , 116793.87730642, 117679.62283388,
#        106164.93097685, 115022.38625149, 108822.16755924,  98193.22122967,
#         99964.7122846 , 105279.18544938, 106164.93097685, 122108.3504712 ,
#        141594.75207541, 103507.69439446, 124765.58705359, 100850.45781206,
#         98193.22122967, 138051.76996555, 107050.67650431, 118565.36836134,
#        136280.27891062, 112365.1496691 , 115908.13177895, 118565.36836134,
#        131851.5512733 , 107050.67650431, 119451.11388881, 108822.16755924,
#         98193.22122967, 131851.5512733 ,  99078.96675714, 114136.64072402,
#        115022.38625149,  99964.7122846 , 110593.65861417, 112365.1496691 ,
# ...

# %%
diff_LR=y_test-y_pred_LR

# %%
res_df=pd.concat([pd.Series(y_pred_LR),pd.Series(y_test),pd.Series(diff_LR)],axis=1)
res_df.columns=['Prediction','Original Data','Diff']

# %%
res_df
# Out:
#         Prediction  Original Data          Diff
# 0    111479.404142         124714  13234.595858
# 1    107936.422032         103760  -4176.422032
# 2     99078.966757          86100 -12978.966757
# 3    114136.640724         181257  67120.359276
# 4     99078.966757         108413   9334.033243
# ..             ...            ...           ...
# 128  120336.859416         172272  51935.140584
# 129  110593.658614         147349  36755.341386
# 130  118565.368361          91100 -27465.368361
# 131  129194.314691         150376  21181.685309
# 132  105279.185449          77500 -27779.185449
#
# [133 rows x 3 columns]

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,LR.predict(x_train),color='blue')

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,LR.predict(x_train),color='blue')
